# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img_book_1 = cv2.imread('Book_1.bmp', cv2.IMREAD_GRAYSCALE)
img_book_2 = cv2.imread('Book_2.bmp', cv2.IMREAD_GRAYSCALE)

# %%
# Imagens já binarizadas
np.unique(img_book_1), np.unique(img_book_2)
# Out:
# (array([  0, 255], dtype=uint8), array([  0, 255], dtype=uint8))

# %%
# Inverte a cor dos pixels
img_book_1 = cv2.bitwise_not(img_book_1)
img_book_2 = cv2.bitwise_not(img_book_2)

# %%
plt.imshow(img_book_1, cmap='gray')

# %%
def exist_A(img, A_format):
    erode_img = cv2.erode(img, A_format, iterations=1)
    if np.any(erode_img == 255):
        print("Existe A")
    else:
        print("Não existe A")
    
    plt.imshow(erode_img, cmap='gray')
    return erode_img

# %%
img_A = cv2.imread('A.jpeg', cv2.IMREAD_GRAYSCALE)

img_A = (img_A < 127).astype('uint8') # Normaliza a imagem entre 0 e 1 e inverte cor

# %%
np.unique(img_A)
# Out:
# array([0, 1], dtype=uint8)

# %%
plt.imshow(img_A, cmap='gray')

# %%
np.unique(img_A)
# Out:
# array([0, 1], dtype=uint8)

# %%
erode_img_1 = exist_A(img_book_1, img_A)
# Out:
# Existe A

# %%
np.unique(erode_img_1, return_counts=True)
# Out:
# (array([  0, 255], dtype=uint8), array([874163,     10]))

# %% [markdown]
# Como extra, com essa abordagem é possível contar também a quantidade de 'A' presente na imagem. No caso temos 10 valores de pixel 255 para essa imagem, ou seja, 10 vezes que a elemento elemento estruturante teve encontro de padrão na imagem, dessa forma, a imagem possui 10 'A's, valor que foi confirmado visualmente.

# %%
erode_img_2 = exist_A(img_book_2, img_A)
# Out:
# Não existe A

# %%
np.unique(erode_img_2, return_counts=True)
# Out:
# (array([0], dtype=uint8), array([705237]))
